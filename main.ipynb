# %%
import os
import random
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import rasterio
from tqdm import tqdm
import pickle

# Helper functions
def read(file):
    with rasterio.open(file) as src:
        return src.read(), src.profile

def get_dates(path, n=None):
    files = os.listdir(path)
    dates = list()
    for f in files:
        f = f.split("_")[0]
        if len(f) == 8:  # Check for valid date format e.g., 20160110
            dates.append(f)
    dates = set(dates)
    if n is not None:
        dates = random.sample(dates, n)
    dates = list(dates)
    dates.sort()
    return dates

# Define the dataset class
class SentinelDataset(Dataset):
    def __init__(self, root_dirs, seqlength=30, preprocess_dirs=None, save_preprocessed=False):
        self.root_dirs = [r.rstrip("/") for r in root_dirs]
        self.seqlength = seqlength
        self.samples = list()
        self.ndates = list()
        self.classids, self.classes = self.read_classes()
        self.preprocess_dirs = preprocess_dirs
        self.save_preprocessed = save_preprocessed
        self.prepare_dataset()

    def read_classes(self):
        classes_path = 'data/sentinel2/lombardia-classes/classes25pc.txt'
        with open(classes_path, 'r') as f:
            classes = f.readlines()
        ids, names = [], []
        for row in classes:
            row = row.replace("\n", "")
            if '|' in row:
                cls_info = row.split('|')
                id_info = [int(x) for x in cls_info[0].split(',')]
                ids.append(id_info)
                names.append(cls_info[1])
        return ids, names

    def prepare_dataset(self):
        for root_dir, preprocess_dir in zip(self.root_dirs, self.preprocess_dirs):
            print("Reading dataset info:", root_dir)
            dirs = []
            for year_dir in os.listdir(root_dir):
                year_path = os.path.join(root_dir, year_dir)
                for tile_dir in os.listdir(year_path):
                    tile_path = os.path.join(year_path, tile_dir)
                    if os.path.isdir(tile_path):
                        dirs.append(tile_path)

            stats = dict(rejected_nopath=0, rejected_length=0, total_samples=0)
            for path in tqdm(dirs):
                if not os.path.exists(path) or not os.path.exists(os.path.join(path, "20160110.tif")):
                    stats["rejected_nopath"] += 1
                    continue
                ndates = len(get_dates(path))
                if ndates < self.seqlength:
                    stats["rejected_length"] += 1
                    continue
                stats["total_samples"] += 1
                self.samples.append((path, preprocess_dir))
                self.ndates.append(ndates)
            self.print_stats(stats)
            if self.save_preprocessed:
                self.save_preprocessed_data()

    def save_preprocessed_data(self):
        for sample, preprocess_dir in self.samples:
            label, profile = read(os.path.join(sample, "y.tif"))
            dates = get_dates(sample, n=self.seqlength)
            data = {
                'label': label,
                'profile': profile,
                'dates': dates
            }
            save_path = os.path.join(preprocess_dir, os.path.basename(sample) + ".pkl")
            os.makedirs(preprocess_dir, exist_ok=True)
            try:
                with open(save_path, 'wb') as f:
                    pickle.dump(data, f)
                print(f"Saved preprocessed data to {save_path}")
            except PermissionError as e:
                print(f"Permission error: {e}")
            except FileNotFoundError as e:
                print(f"File not found: {e}")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sample_path, preprocess_dir = self.samples[idx]
        label, profile = read(os.path.join(sample_path, "y.tif"))
        dates = get_dates(sample_path, n=self.seqlength)
        data_10m, data_20m, data_60m = [], [], []
        for date in dates:
            data_10m.append(read(os.path.join(sample_path, date + "_10m.tif"))[0])
            data_20m.append(read(os.path.join(sample_path, date + "_20m.tif"))[0])
            data_60m.append(read(os.path.join(sample_path, date + "_60m.tif"))[0])
        data_10m = np.array(data_10m) * 1e-4
        data_20m = np.array(data_20m) * 1e-4
        data_60m = np.array(data_60m) * 1e-4
        data_20m = torch.from_numpy(data_20m)
        data_60m = torch.from_numpy(data_60m)
        data_20m = torch.nn.functional.interpolate(data_20m, size=data_10m.shape[2:4])
        data_60m = torch.nn.functional.interpolate(data_60m, size=data_10m.shape[2:4])
        data = torch.cat((torch.from_numpy(data_10m), data_20m, data_60m), 1)
        data = data.permute(1, 0, 2, 3).float()
        label = torch.from_numpy(label).long()
        return data, label

    def print_stats(self, stats):
        print_lst = list()
        for k, v in zip(stats.keys(), stats.values()):
            print_lst.append("{}:{}".format(k, v))
        print('\n', ", ".join(print_lst))

# Define paths and parameters
root_paths = ['data/sentinel2/lombardia', 'data/sentinel2/lombardia2']
preprocess_dirs = ['data/sentinel2/lombardia_preprocessed', 'data/sentinel2/lombardia2_preprocessed']

# Initialize and prepare dataset
dataset = SentinelDataset(root_paths, seqlength=30, preprocess_dirs=preprocess_dirs, save_preprocessed=True)

# Create DataLoader for training and validation
batch_size = 16
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)

# Verify DataLoader
for batch in train_loader:
    inputs, labels = batch
    print('Input shape:', inputs.shape)
    print('Label shape:', labels.shape)
    break
# Out:
# Reading dataset info: data/sentinel2/lombardia
# 100%|██████████| 13312/13312 [00:06<00:00, 2006.78it/s]
# C:\Users\Richa\AppData\Local\Temp\ipykernel_18552\4253084667.py:24: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   dates = random.sample(dates, n)
#  rejected_nopath:9984, rejected_length:0, total_samples:3328
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\10.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\100.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1000.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1001.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1002.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1003.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1004.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1005.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1006.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1007.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1008.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1009.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\101.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1010.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1011.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1012.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1013.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1014.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1015.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1016.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1017.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1018.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1019.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\102.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1020.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1021.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1022.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1023.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1024.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1025.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1026.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1027.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1028.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1029.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\103.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1030.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1031.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1032.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1033.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1034.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1035.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1036.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1037.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1038.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1039.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\104.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1040.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1041.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1042.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1043.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1044.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1045.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1046.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1047.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1048.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1049.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\105.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1050.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1051.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1052.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1053.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1054.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1055.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1056.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1057.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1058.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1059.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\106.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1060.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1061.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1062.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1063.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1064.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1065.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1066.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1067.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1068.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1069.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\107.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1070.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1071.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1072.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1073.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1074.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1075.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1076.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1077.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1078.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1079.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\108.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1080.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1081.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1082.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1083.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1084.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1085.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1086.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1087.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1088.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1089.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\109.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1090.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1091.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1092.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1093.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1094.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1095.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1096.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1097.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1098.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1099.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\11.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\110.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1100.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1101.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1102.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1103.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1104.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1105.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1106.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1107.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1108.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1109.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\111.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1110.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1111.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1112.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1113.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1114.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1115.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1116.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1117.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1118.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1119.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\112.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1120.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1121.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1122.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1123.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1124.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1125.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1126.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1127.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1128.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1129.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\113.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1130.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1131.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1132.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1133.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1134.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1135.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1136.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1137.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1138.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1139.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\114.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1140.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1141.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1142.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1143.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1144.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1145.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1146.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1147.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1148.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1149.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\115.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1150.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1151.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1152.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1153.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1154.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1155.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1156.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1157.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1158.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1159.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\116.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1160.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1161.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1162.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1163.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1164.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1165.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1166.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1167.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1168.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1169.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\117.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1170.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1171.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1172.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1173.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1174.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1175.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1176.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1177.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1178.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1179.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\118.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1180.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1181.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1182.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1183.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1184.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1185.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1186.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1187.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1188.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1189.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\119.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1190.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1191.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1192.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1193.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1194.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1195.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1196.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1197.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1198.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1199.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\12.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\120.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1200.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1201.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1202.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1203.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1204.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1205.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1206.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1207.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1208.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1209.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\121.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1210.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1211.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1212.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1213.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1214.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1215.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1216.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1217.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1218.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1219.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\122.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1220.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1221.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1222.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1223.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1224.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1225.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1226.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1227.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1228.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1229.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\123.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1230.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1231.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1232.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1233.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1234.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1235.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1236.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1237.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1238.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1239.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\124.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1240.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1241.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1242.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1243.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1244.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1245.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1246.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1247.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1248.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1249.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\125.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1250.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1251.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1252.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1253.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1254.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1255.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1256.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1257.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1258.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1259.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\126.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1260.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1261.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1262.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1263.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1264.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1265.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1266.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1267.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1268.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1269.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\127.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1270.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1271.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1272.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1273.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1274.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1275.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1276.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1277.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1278.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1279.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\128.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1280.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1281.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1282.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1283.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1284.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1285.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1286.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1287.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1288.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1289.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\129.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1290.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1291.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1292.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1293.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1294.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1295.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1296.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1297.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1298.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1299.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\13.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\130.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1300.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1301.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1302.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1303.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1304.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1305.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1306.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1307.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1308.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1309.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\131.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1310.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1311.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1312.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1313.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1314.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1315.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1316.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1317.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1318.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1319.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\132.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1320.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1321.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1322.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1323.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1324.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1325.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1326.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1327.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1328.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1329.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\133.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1330.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1331.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1332.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1333.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1334.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1335.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1336.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1337.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1338.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1339.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\134.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1340.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1341.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1342.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1343.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1344.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1345.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1346.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1347.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1348.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1349.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\135.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1350.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1351.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1352.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1353.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1354.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1355.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1356.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1357.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1358.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1359.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\136.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1360.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1361.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1362.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1363.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1364.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1365.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1366.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1367.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1368.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1369.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\137.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1370.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1371.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1372.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1373.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1374.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1375.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1376.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1377.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1378.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1379.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\138.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1380.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1381.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1382.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1383.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1384.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1385.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1386.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1387.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1388.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1389.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\139.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1390.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1391.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1392.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1393.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1394.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1395.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1396.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1397.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1398.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1399.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\14.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\140.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1400.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1401.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1402.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1403.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1404.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1405.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1406.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1407.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1408.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1409.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\141.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1410.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1411.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1412.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1413.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1414.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1415.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1416.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1417.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1418.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1419.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\142.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1420.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1421.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1422.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1423.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1424.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1425.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1426.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1427.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1428.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1429.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\143.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1430.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1431.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1432.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1433.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1434.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1435.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1436.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1437.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1438.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1439.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\144.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1440.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1441.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1442.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1443.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1444.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1445.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1446.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1447.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1448.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1449.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\145.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1450.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1451.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1452.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1453.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1454.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1455.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1456.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1457.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1458.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1459.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\146.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1460.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1461.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1462.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1463.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1464.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1465.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1466.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1467.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1468.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1469.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\147.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1470.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1471.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1472.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1473.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1474.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1475.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1476.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1477.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1478.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1479.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\148.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1480.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1481.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1482.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1483.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1484.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1485.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1486.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1487.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1488.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1489.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\149.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1490.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1491.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1492.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1493.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1494.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1495.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1496.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1497.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1498.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1499.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\15.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\150.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1500.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1501.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1502.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1503.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1504.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1505.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1506.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1507.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1508.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1509.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\151.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1510.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1511.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1512.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1513.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1514.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1515.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1516.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1517.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1518.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1519.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\152.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1520.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1521.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1522.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1523.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1524.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1525.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1526.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1527.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1528.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1529.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\153.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1530.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1531.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1532.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1533.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1534.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1535.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1536.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1537.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1538.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1539.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\154.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1540.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1541.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1542.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1543.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1544.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1545.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1546.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1547.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1548.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1549.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\155.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1550.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1551.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1552.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1553.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1554.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1555.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1556.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1557.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1558.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1559.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\156.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1560.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1561.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1562.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1563.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1564.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1565.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1566.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1567.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1568.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1569.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\157.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1570.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1571.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1572.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1573.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1574.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1575.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1576.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1577.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\1578.pkl
# ...
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\801.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\802.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\803.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\804.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\805.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\806.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\807.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\808.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\809.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\81.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\810.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\811.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\812.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\813.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\814.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\815.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\816.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\817.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\818.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\819.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\82.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\820.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\821.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\822.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\823.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\824.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\825.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\826.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\827.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\828.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\829.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\83.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\830.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\831.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\832.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\833.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\834.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\835.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\836.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\837.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\838.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\839.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\84.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\840.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\841.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\842.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\843.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\844.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\845.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\846.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\847.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\848.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\849.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\85.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\850.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\851.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\852.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\853.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\854.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\855.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\856.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\857.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\858.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\859.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\86.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\860.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\861.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\862.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\863.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\864.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\865.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\866.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\867.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\868.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\869.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\87.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\870.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\871.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\872.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\873.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\874.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\875.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\876.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\877.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\878.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\879.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\88.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\880.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\881.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\882.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\883.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\884.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\885.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\886.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\887.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\888.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\889.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\89.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\890.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\891.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\892.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\893.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\894.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\895.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\896.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\897.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\898.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\899.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\9.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\90.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\900.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\901.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\902.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\903.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\904.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\905.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\906.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\907.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\908.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\909.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\91.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\910.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\911.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\912.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\913.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\914.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\915.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\916.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\917.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\918.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\919.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\92.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\920.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\921.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\922.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\923.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\924.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\925.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\926.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\927.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\928.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\929.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\93.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\930.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\931.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\932.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\933.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\934.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\935.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\936.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\937.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\938.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\939.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\94.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\940.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\941.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\942.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\943.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\944.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\945.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\946.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\947.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\948.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\949.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\95.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\950.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\951.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\952.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\953.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\954.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\955.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\956.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\957.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\958.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\959.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\96.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\960.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\961.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\962.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\963.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\964.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\965.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\966.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\967.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\968.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\969.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\97.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\970.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\971.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\972.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\973.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\974.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\975.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\976.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\977.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\978.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\979.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\98.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\980.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\981.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\982.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\983.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\984.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\985.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\986.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\987.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\988.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\989.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\99.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\990.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\991.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\992.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\993.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\994.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\995.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\996.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\997.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\998.pkl
# Saved preprocessed data to data/sentinel2/lombardia_preprocessed\999.pkl

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import resnet50

class ASPP(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ASPP, self).__init__()
        self.atrous_block1 = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0, dilation=1, bias=False)
        self.atrous_block6 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=6, dilation=6, bias=False)
        self.atrous_block12 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=12, dilation=12, bias=False)
        self.atrous_block18 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=18, dilation=18, bias=False)
        self.conv_1x1_output = nn.Conv2d(out_channels * 4, out_channels, kernel_size=1, stride=1, padding=0, bias=False)
        self.batch_norm = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, x):
        x1 = self.atrous_block1(x)
        x2 = self.atrous_block6(x)
        x3 = self.atrous_block12(x)
        x4 = self.atrous_block18(x)
        x = torch.cat((x1, x2, x3, x4), dim=1)
        x = self.conv_1x1_output(x)
        x = self.batch_norm(x)
        return self.relu(x)

class DeepLabV3(nn.Module):
    def __init__(self, num_classes, in_channels=3, pretrained=True):
        super(DeepLabV3, self).__init__()
        self.backbone = resnet50(pretrained=pretrained)
        self.backbone = nn.Sequential(*list(self.backbone.children())[:-2])
        self.aspp = ASPP(2048, 256)
        self.conv1 = nn.Conv2d(256, 256, kernel_size=3, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(256)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(256, num_classes, kernel_size=1)

    def forward(self, x):
        x = self.backbone(x)
        x = self.aspp(x)
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.conv2(x)
        return F.interpolate(x, scale_factor=8, mode='bilinear', align_corners=True)

# Define number of classes based on your dataset
num_classes = 22
model = DeepLabV3(num_classes=num_classes, in_channels=3, pretrained=True)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# %%
import optuna
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# Define the objective function for Optuna
def objective(trial):
    # Hyperparameters to tune
    lr = trial.suggest_float('lr', 1e-5, 1e-2, log=True)
    weight_decay = trial.suggest_float('weight_decay', 1e-5, 1e-2, log=True)
    gamma = trial.suggest_float('gamma', 0.1, 0.9)
    step_size = trial.suggest_int('step_size', 1, 10)
    batch_size = trial.suggest_int('batch_size', 8, 32)
    
    # Create DataLoader with the trial's batch size
    train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4)
    val_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=4)
    
    # Initialize the model, criterion, optimizer, and scheduler with trial's hyperparameters
    model = DeepLabV3(num_classes=num_classes, in_channels=3, pretrained=True)
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = StepLR(optimizer, step_size=step_size, gamma=gamma)
    criterion = nn.CrossEntropyLoss()
    
    # Training loop for a few epochs
    num_epochs = 5  # You can adjust this for faster tuning
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
        scheduler.step()
    
    # Validation
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
    
    val_loss /= len(val_loader.dataset)
    return val_loss

# Run the optimization
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

# Print the best hyperparameters
print("Best parameters:", study.best_params)
print("Best validation loss:", study.best_value)

# Best hyperparameters from Optuna
best_params = study.best_params

# Create DataLoader with the best batch size
train_loader = DataLoader(dataset, batch_size=best_params['batch_size'], shuffle=True, num_workers=4)
val_loader = DataLoader(dataset, batch_size=best_params['batch_size'], shuffle=False, num_workers=4)

# Initialize the model, criterion, optimizer, and scheduler with best hyperparameters
model = DeepLabV3(num_classes=num_classes, in_channels=3, pretrained=True)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=best_params['weight_decay'])
scheduler = StepLR(optimizer, step_size=best_params['step_size'], gamma=best_params['gamma'])

# Move model to the appropriate device
model.to(device)

# Print model architecture to verify
print(model)
# Out:
# [I 2024-07-03 20:44:40,134] A new study created in memory with name: no-name-74537ca6-06e5-4613-a92e-e4a43421ea3a
# c:\Users\Richa\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Richa\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Training loop
num_epochs = 25
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)

    # Validation
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    val_loss /= len(val_loader.dataset)
    val_accuracy = correct / total

    print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}')
    
    # Adjust the learning rate
    scheduler.step()

print('Training complete')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Best hyperparameters from Optuna
# ----> 2 best_params = study.best_params
#       4 # Create DataLoader with the best batch size
#       5 train_loader = DataLoader(train_dataset, batch_size=best_params['batch_size'], shuffle=True, num_workers=4)
#
# NameError: name 'study' is not defined

# %%
# Evaluate the model on the validation set
model.eval()
val_loss = 0.0
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        val_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

val_loss /= len(val_loader.dataset)
val_accuracy = correct / total

print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Save the model
torch.save(model.state_dict(), 'best_model.pth')
print('Model saved to best_model.pth')
